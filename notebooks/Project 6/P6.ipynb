// %%
#include <iostream>
using namespace std;

// %%
#pragma cling load("grid.h")
#pragma cling load("grid.cpp")
#pragma cling load("shape.h")
#pragma cling load("shape.cpp")
//#pragma cling load("circle.h")
//#pragma cling load("circle.cpp")
#pragma cling load("point.h")
#pragma cling load("point.cpp")
#pragma cling load("square.h")
#pragma cling load("square.cpp")
#pragma cling load("triangle.h")
#pragma cling load("triangle.cpp")

// %%
Grid g;
Square bigSQ(0,0,24);
Square smallSQ(2,5,4);
Point tl(0,0,'+');
Point br(23,59,'+');
Point ques(15,3,'?');
Triangle def(10,10);

//tl.draw(g);
br.draw(g);
bigSQ.draw(g);
smallSQ.draw(g);
ques.draw(g);
def.draw(g);

g.print();
// Out:
// ************************
// *                      *
// *                      *
// *              ?       *
// *                      *
// * ****                 *
// * *  *                 *
// * *  *                 *
// * ****                 *
// *                      *
// *         +            *
// *        + +           *
// *       +++++          *
// *                      *
// *                      *
// *                      *
// *                      *
// *                      *
// *                      *
// *                      *
// *                      *
// *                      *
// *                      *
// ************************
